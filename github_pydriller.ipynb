# %%
from pydriller import Repository

# %%
for commit in Repository('https://github.com/GeoNode/geonode', order= "author-date-order").traverse_commits():
    print('Hash {}, author {}'.format(commit.hash, commit.author.name))
# Out:
# Hash 845d21bbd0d342b849e23e315a2b2208f7cd5abe, author whit
# Hash a2345429e0a26a46c5e6c4de77f88ab15bbd118c, author whit
# Hash ea3c56bc9969bda377bc060796f4d40fc794675b, author whit
# Hash 7bae5032b5cc01e4dddf5e47917d069f2b9b3a82, author whit
# Hash b6b6de400838afbfc6ce46adf9c592f4ad3fa606, author whit
# Hash 06a761161fc10b61ee87ac50497c31b0918f3817, author whit
# Hash 49aa25f063e7ea11846c915a4d715ec8a209a4d9, author dwinslow
# Hash 15871f961475fd31d007a516ebaaf9df17c95c3b, author whit
# Hash f6ae1033b6b1dabb381afa92cd938187dc2c2b55, author whit
# Hash 91768613a001af037a4a0fbbc678d7582a124971, author whit
# Hash f34f20d93bda68dc23c7cb5600c3a51d7a3cf326, author whit
# Hash df47b94688b9b4d9f31820c9a4dd4822c05c3a38, author whit
# Hash 01aaa78a4ab542047d894f908fb54efb94c09191, author whit
# Hash 9902a8f03c720bcc0cffecf2d4cb8fc7e3dd22fd, author whit
# Hash 4eb735b9d17c6d63cfb4d8bd6ec51c57ed4c7a8f, author whit
# Hash 19156f8c9d4ac36688b59d6255db260f9280db14, author whit
# ...
